# %%
import cv2  
import numpy as np
import matplotlib.pyplot as plt

# %%
#Dimensiones de la imagen a crear
ancho = 200
alto = 200

# %%
#Crea una imagen en gris, por ello tiene un único plano
gris_img = np.zeros((ancho,alto,1), dtype = np.uint8)
#Muestra dimensiones de la imagen creada
print(gris_img.shape)
# Out:
# (200, 200, 1)

# %%
#Crea una imagen con tres planos
color_img = np.zeros((200,200,3), dtype = np.uint8)
#Dimensiones
print(color_img.shape)
#Visualiza sin especificar el mapa de color gris
plt.imshow(color_img) 
plt.show()
# Out:
# (200, 200, 3)

# %%
cv2.line(color_img,(100,25),(100,175),(0,255,255),1)

pts = np.array([[50,175],[100,25],[150,175]], np.int32)
pts = pts.reshape((-1,1,2))
cv2.polylines(color_img,[pts],True,(0,255,255))

cv2.circle(color_img,(100,130), 30, (0,0,255), 1)

plt.imshow(color_img) 
plt.show()
